# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install Citipy
# Out:
# Requirement already satisfied: Citipy in c:\programdata\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\programdata\anaconda3\lib\site-packages (from Citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
# Import API key
from api_keys import weather_api_key
from scipy.stats import linregress
import scipy.stats as st

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
## Generate Cities List
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Set base url and units variables, and combine them to get the query url
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Create empty lists to store the data for each field
city_id_list = []
city_name_list = []
country_list = []
lng_list = []
lat_list = []
temp_list = []
humidity_list = []
clouds_list = []
wind_speed_list = []

# Loop through cities
for city in cities:
    
    # Get the JSON response from the OpenWeather API
    response_json = requests.get(query_url + city).json()
    
    # Start the error handling
    # Retrieve the items for each field and append them to the empty lists  
    try:
        
        city_id = response_json['id']
        city_id_list.append(city_id)
            
        city_name = response_json['name']
        city_name_list.append(city_name)
        
        country_name = response_json['sys']['country']
        country_list.append(country_name)

        lng = response_json['coord']['lon']
        lng_list.append(lng)

        lat = response_json['coord']['lat']
        lat_list.append(lat)

        temp = response_json['main']['temp']
        temp_list.append(temp)

        humidity = response_json['main']['humidity']
        humidity_list.append(humidity)

        clouds = response_json['clouds']['all']
        clouds_list.append(clouds)

        wind_speed = response_json['wind']['speed']
        wind_speed_list.append(wind_speed)
    
        print(f"City Name: {city}, City ID: {city_id}")
    
    # Print error message and move on to the next city if there is an error
    except:
        
        print(f"City{city} is not found...")
# Out:
# City Name: hobart, City ID: 2163355
# City Name: upernavik, City ID: 3418910
# City Name: ushuaia, City ID: 3833367
# City Name: talara, City ID: 3691582
# City Name: busselton, City ID: 2075265
# City Name: lukow, City ID: 765749
# City Name: wanxian, City ID: 1791748
# City Name: santa isabel do rio negro, City ID: 3662489
# City Name: saint-philippe, City ID: 935215
# City Name: punta arenas, City ID: 3874787
# City Name: bambous virieux, City ID: 1106677
# City Name: bonavista, City ID: 5905393
# City Name: cape town, City ID: 3369157
# City Name: necochea, City ID: 3430443
# City Name: muros, City ID: 3115824
# City Name: mataura, City ID: 6201424
# City Name: vaini, City ID: 4032243
# City Name: fortuna, City ID: 5563839
# City Name: tazmalt, City ID: 2477537
# City Name: port alfred, City ID: 964432
# City Name: new norfolk, City ID: 2155415
# City Name: margate, City ID: 2643044
# City Name: makakilo city, City ID: 5850554
# City Name: hilo, City ID: 5855927
# Citytaolanaro is not found...
# City Name: avarua, City ID: 4035715
# City Name: gazanjyk, City ID: 161974
# City Name: bredasdorp, City ID: 1015776
# City Name: hithadhoo, City ID: 1282256
# City Name: rikitea, City ID: 4030556
# City Name: lisakovsk, City ID: 1521315
# City Name: albany, City ID: 5106841
# City Name: boa vista, City ID: 3664980
# City Name: goderich, City ID: 5962442
# City Name: carnarvon, City ID: 2074865
# City Name: flinders, City ID: 6255012
# City Name: san patricio, City ID: 4726521
# City Name: ostrovnoy, City ID: 556268
# City Name: itaituba, City ID: 3397967
# City Name: castro, City ID: 3466704
# Cityumzimvubu is not found...
# City Name: namibe, City ID: 3347019
# Citykadykchan is not found...
# City Name: lompoc, City ID: 5367788
# City Name: kavieng, City ID: 2094342
# City Name: bluff, City ID: 2206939
# City Name: khatanga, City ID: 2022572
# Cityondorhaan is not found...
# City Name: grand gaube, City ID: 934479
# City Name: hofn, City ID: 2630299
# Citysentyabrskiy is not found...
# City Name: georgetown, City ID: 1735106
# City Name: moose factory, City ID: 6078372
# City Name: kilindoni, City ID: 157429
# City Name: djibo, City ID: 2361177
# City Name: raton, City ID: 5486795
# City Name: port elizabeth, City ID: 964420
# City Name: topolovgrad, City ID: 726384
# City Name: faanui, City ID: 4034551
# City Name: marsaxlokk, City ID: 2562247
# City Name: guerrero negro, City ID: 4021858
# City Name: korla, City ID: 1529376
# City Name: salmas, City ID: 117656
# City Name: lajoskomarom, City ID: 3049013
# City Name: kapaa, City ID: 5848280
# Citylinapacan is not found...
# City Name: iqaluit, City ID: 5983720
# City Name: luderitz, City ID: 3355672
# Citylitoral del san juan is not found...
# City Name: yellowknife, City ID: 6185377
# City Name: arman, City ID: 2127060
# City Name: tasiilaq, City ID: 3424607
# Citymarcona is not found...
# City Name: puerto ayora, City ID: 3652764
# City Name: hermanus, City ID: 3366880
# City Name: verkhnevilyuysk, City ID: 2013639
# City Name: hasaki, City ID: 2112802
# City Name: victoria, City ID: 1819729
# City Name: ribeira grande, City ID: 3372707
# City Name: safaga, City ID: 358620
# City Name: laguna, City ID: 5364271
# City Name: kruisfontein, City ID: 986717
# City Name: hambantota, City ID: 1244926
# City Name: banchory, City ID: 2656405
# City Name: morehead, City ID: 4301317
# City Name: nome, City ID: 5870133
# City Name: qaanaaq, City ID: 3831208
# Citynizhneyansk is not found...
# City Name: camabatela, City ID: 2242885
# City Name: havre-saint-pierre, City ID: 5972291
# City Name: poum, City ID: 2138555
# City Name: gat, City ID: 293842
# City Name: cherskiy, City ID: 2126199
# City Name: jam sahib, City ID: 1403734
# Citytsihombe is not found...
# City Name: lebu, City ID: 3883457
# City Name: irara, City ID: 3461022
# City Name: chokurdakh, City ID: 2126123
# City Name: saskylakh, City ID: 2017155
# City Name: asau, City ID: 686090
# City Name: morrope, City ID: 3694586
# City Name: butaritari, City ID: 2110227
# City Name: broome, City ID: 5110365
# City Name: barrow, City ID: 5880054
# City Name: samsun, City ID: 740263
# City Name: saint george, City ID: 5546220
# City Name: kaabong, City ID: 233093
# City Name: hami, City ID: 1529484
# City Name: srednekolymsk, City ID: 2121025
# Cityilloqqortoormiut is not found...
# City Name: nouadhibou, City ID: 2377457
# City Name: vila franca do campo, City ID: 3372472
# City Name: norman wells, City ID: 6089245
# City Name: kaeo, City ID: 2189343
# City Name: yarovoye, City ID: 1486340
# City Name: montepuez, City ID: 1037125
# City Name: aklavik, City ID: 5882953
# City Name: kaitangata, City ID: 2208248
# City Name: airai, City ID: 1651810
# City Name: ambilobe, City ID: 1082243
# City Name: beamsville, City ID: 5895710
# City Name: brodokalmak, City ID: 1508802
# City Name: amursk, City ID: 2027749
# City Name: veseloyarsk, City ID: 1487164
# City Name: kavaratti, City ID: 1267390
# City Name: syriam, City ID: 1295395
# Citytumannyy is not found...
# City Name: thompson, City ID: 6165406
# City Name: sistranda, City ID: 3139597
# City Name: kristiansund, City ID: 6453331
# City Name: mendoza, City ID: 3844421
# City Name: esperance, City ID: 2071860
# Citymys shmidta is not found...
# City Name: oranjemund, City ID: 3354071
# City Name: paamiut, City ID: 3421193
# City Name: mogadishu, City ID: 53654
# City Name: makokou, City ID: 2399371
# City Name: undory, City ID: 479021
# City Name: kipini, City ID: 191675
# City Name: atuona, City ID: 4020109
# City Name: tazovskiy, City ID: 1489853
# City Name: marsabit, City ID: 187585
# City Name: tuktoyaktuk, City ID: 6170031
# City Name: nanyang, City ID: 1799629
# City Name: naliya, City ID: 1262062
# City Name: varhaug, City ID: 3132644
# City Name: bousso, City ID: 2434584
# City Name: lavrentiya, City ID: 4031637
# City Name: tessalit, City ID: 2449893
# City Name: nemuro, City ID: 2128975
# City Name: mezen, City ID: 527321
# Citybelushya guba is not found...
# City Name: tiksi, City ID: 2015306
# City Name: tabas, City ID: 113659
# City Name: karaton, City ID: 1630058
# City Name: novyy urengoy, City ID: 1496511
# City Name: purpe, City ID: 1539210
# City Name: severnyy, City ID: 496358
# City Name: clyde river, City ID: 5924351
# City Name: kozulka, City ID: 687093
# Citysaleaula is not found...
# Citytidore is not found...
# Citymaghama is not found...
# City Name: bilibino, City ID: 2126682
# City Name: port hardy, City ID: 6111862
# City Name: iquique, City ID: 3887127
# City Name: general roca, City ID: 3855065
# City Name: bilma, City ID: 2446796
# Citytoliary is not found...
# City Name: provideniya, City ID: 4031574
# City Name: iskateley, City ID: 866062
# City Name: port lincoln, City ID: 2063036
# City Name: bethel, City ID: 5282297
# City Name: cobija, City ID: 3919998
# City Name: carutapera, City ID: 3402648
# City Name: east london, City ID: 1006984
# City Name: nauta, City ID: 3692020
# City Name: tongren, City ID: 1792592
# City Name: saldanha, City ID: 3361934
# City Name: gobabis, City ID: 3357247
# City Name: nishihara, City ID: 1855342
# Citybolungarvik is not found...
# City Name: kawalu, City ID: 1640902
# City Name: sosnovo-ozerskoye, City ID: 2016216
# City Name: eyrarbakki, City ID: 3413604
# City Name: ballina, City ID: 2177069
# City Name: timmins, City ID: 6166739
# City Name: katsuura, City ID: 2112309
# City Name: sao joao da barra, City ID: 3448903
# City Name: kuruman, City ID: 986134
# City Name: sao filipe, City ID: 3374210
# City Name: nanortalik, City ID: 3421765
# City Name: sterling, City ID: 4787534
# City Name: husavik, City ID: 2629833
# City Name: pathein, City ID: 1328421
# Citysatitoa is not found...
# City Name: kovernino, City ID: 543494
# City Name: batemans bay, City ID: 2176639
# City Name: port-cartier, City ID: 6111696
# City Name: bandarbeyla, City ID: 64814
# City Name: svobodnyy, City ID: 2015833
# City Name: westport, City ID: 4845585
# City Name: jamestown, City ID: 5122534
# City Name: palu, City ID: 1633034
# City Name: lyantonde, City ID: 229599
# City Name: panzhihua, City ID: 6929460
# City Name: choya, City ID: 1507745
# City Name: chase, City ID: 5920381
# City Name: thinadhoo, City ID: 1337610
# Citytunduru is not found...
# City Name: fairbanks, City ID: 5861897
# City Name: pando, City ID: 3441354
# City Name: haines junction, City ID: 5969025
# Cityutiroa is not found...
# City Name: pisco, City ID: 3932145
# City Name: kahului, City ID: 5847411
# City Name: ivanovice na hane, City ID: 3074614
# City Name: ilulissat, City ID: 3423146
# City Name: whitianga, City ID: 2179103
# City Name: bedford, City ID: 2656046
# City Name: kieta, City ID: 2094027
# City Name: olinda, City ID: 3393536
# City Name: ponta delgada, City ID: 3372783
# City Name: ovalle, City ID: 3877918
# City Name: auki, City ID: 2109701
# City Name: lorengau, City ID: 2092164
# City Name: nantucket, City ID: 4944903
# City Name: santa, City ID: 1688420
# City Name: burla, City ID: 1275050
# City Name: longyearbyen, City ID: 2729907
# City Name: palmer, City ID: 4946620
# City Name: converse, City ID: 4683021
# City Name: kodiak, City ID: 5866583
# City Name: saint-gilles, City ID: 2979679
# City Name: yangambi, City ID: 203717
# City Name: toyooka, City ID: 1849831
# City Name: el alto, City ID: 3697441
# City Name: lasa, City ID: 3175096
# City Name: mar del plata, City ID: 3430863
# City Name: qui nhon, City ID: 1568574
# City Name: atar, City ID: 2381334
# City Name: constantine, City ID: 2501152
# City Name: fort nelson, City ID: 5955902
# City Name: sri aman, City ID: 1735799
# City Name: lagoa, City ID: 3372964
# City Name: saint-raymond, City ID: 6138980
# City Name: torbay, City ID: 6167817
# City Name: kabala, City ID: 2408329
# City Name: novo aripuana, City ID: 3663142
# City Name: bonito, City ID: 3469294
# Citykhonuu is not found...
# City Name: mahebourg, City ID: 934322
# City Name: carballo, City ID: 3126369
# City Name: maine-soroa, City ID: 2441447
# City Name: dikson, City ID: 1507390
# City Name: hereford, City ID: 2647074
# City Name: ponta do sol, City ID: 2264557
# Citybarentsburg is not found...
# City Name: arraial do cabo, City ID: 3471451
# City Name: valle de san juan, City ID: 3666309
# City Name: batagay, City ID: 2027044
# City Name: nizwa, City ID: 286987
# City Name: port blair, City ID: 1259385
# City Name: bengkulu, City ID: 1649150
# City Name: kushiro, City ID: 2129376
# City Name: north bend, City ID: 5742974
# City Name: henties bay, City ID: 3356832
# Citybury saint edmunds is not found...
# City Name: nanakuli, City ID: 5851349
# City Name: ende, City ID: 1644932
# City Name: luanda, City ID: 2240449
# City Name: nawa, City ID: 1261647
# City Name: ancud, City ID: 3899695
# City Name: berlevag, City ID: 780687
# City Name: umm lajj, City ID: 100926
# City Name: mizdah, City ID: 2214827
# City Name: bagdarin, City ID: 2027244
# City Name: shimoda, City ID: 1852357
# City Name: tacuarembo, City ID: 3440034
# City Name: dunedin, City ID: 2191562
# City Name: havelock, City ID: 4470244
# City Name: san rafael, City ID: 3836669
# City Name: cazones, City ID: 3531391
# City Name: cambuquira, City ID: 3467952
# City Name: mapiri, City ID: 3910758
# Citygrand river south east is not found...
# City Name: tuatapere, City ID: 2180815
# City Name: baykit, City ID: 1510689
# City Name: chibuto, City ID: 1049861
# City Name: genhe, City ID: 2037252
# City Name: seoul, City ID: 1835848
# City Name: kozhva, City ID: 543246
# City Name: port macquarie, City ID: 2152659
# City Name: loandjili, City ID: 2258378
# City Name: nikolskoye, City ID: 546105
# City Name: bali, City ID: 1650535
# City Name: chepen, City ID: 3698390
# City Name: banposh, City ID: 1277247
# City Name: druzhba, City ID: 709584
# City Name: halifax, City ID: 6324729
# City Name: wajid, City ID: 50814
# Citylolua is not found...
# City Name: comodoro rivadavia, City ID: 3860443
# City Name: puro, City ID: 1692364
# City Name: kautokeino, City ID: 779330
# City Name: rawson, City ID: 3839307
# Citystoyba is not found...
# City Name: moyale, City ID: 186180
# Citypaucartambo is not found...
# Cityamderma is not found...
# Cityattawapiskat is not found...
# City Name: teya, City ID: 1489656
# City Name: quatre cocos, City ID: 1106643
# City Name: peruibe, City ID: 3454061
# City Name: griffith, City ID: 4920986
# Cityvaitupu is not found...
# City Name: santa cruz del sur, City ID: 3537840
# City Name: ouadda, City ID: 236901
# City Name: bukama, City ID: 217834
# City Name: geraldton, City ID: 2070998
# City Name: pangnirtung, City ID: 6096551
# City Name: severo-kurilsk, City ID: 2121385
# Citybuariki is not found...
# City Name: san cristobal, City ID: 3628473
# City Name: prince rupert, City ID: 6113406
# City Name: tura, City ID: 1254046
# City Name: wamba, City ID: 2319257
# City Name: alakurtti, City ID: 583472
# City Name: mount isa, City ID: 2065594
# City Name: sokolo, City ID: 2450849
# City Name: virginia beach, City ID: 4791259
# City Name: gisborne, City ID: 2206854
# City Name: santa maria do suacui, City ID: 3450057
# City Name: souillac, City ID: 933995
# City Name: tiarei, City ID: 4033356
# City Name: codrington, City ID: 2171099
# City Name: antigonish, City ID: 5886182
# City Name: kandrian, City ID: 2094746
# City Name: sorochinsk, City ID: 490554
# City Name: fare, City ID: 4034496
# City Name: cayenne, City ID: 3382160
# City Name: nuuk, City ID: 3421319
# City Name: dresden, City ID: 2935022
# City Name: kiama, City ID: 2161515
# City Name: kesan, City ID: 743439
# City Name: yumen, City ID: 1528998
# City Name: komatsu, City ID: 1858910
# City Name: merauke, City ID: 2082539
# City Name: maceio, City ID: 3395981
# City Name: emerald, City ID: 2167426
# City Name: buenaventura, City ID: 3688451
# City Name: miraflores, City ID: 3761194
# City Name: lalmohan, City ID: 1185251
# City Name: warrington, City ID: 2634739
# City Name: pitimbu, City ID: 3391889
# Citybababe is not found...
# City Name: ocos, City ID: 3592086
# City Name: petropavlovsk-kamchatskiy, City ID: 2122104
# City Name: manyana, City ID: 933416
# City Name: srivardhan, City ID: 1255619
# Citypalabuhanratu is not found...
# City Name: hangu, City ID: 1808931
# Cityurdzhar is not found...
# City Name: ossora, City ID: 2122389
# City Name: los llanos de aridane, City ID: 2514651
# City Name: rocha, City ID: 3440777
# City Name: pout, City ID: 2246606
# City Name: mount gambier, City ID: 2156643
# City Name: narsaq, City ID: 3421719
# City Name: esmeraldas, City ID: 3464008
# City Name: khasan, City ID: 2039557
# City Name: breyten, City ID: 1015694
# City Name: kholodnyy, City ID: 2124611
# City Name: gladstone, City ID: 2165478
# City Name: pacific grove, City ID: 5380437
# Citywahran is not found...
# City Name: antofagasta, City ID: 3899539
# City Name: darnah, City ID: 87205
# City Name: kirakira, City ID: 2178753
# City Name: arys, City ID: 1526168
# City Name: hun, City ID: 2216645
# City Name: erdaojiang, City ID: 2037494
# City Name: mayo, City ID: 4362001
# City Name: valley city, City ID: 5062292
# City Name: sangareddi, City ID: 1257431
# City Name: upata, City ID: 3625710
# City Name: dezful, City ID: 136256
# City Name: broken hill, City ID: 2173911
# City Name: vestmannaeyjar, City ID: 3412093
# City Name: marakkanam, City ID: 1263564
# City Name: kenai, City ID: 5866063
# City Name: deputatskiy, City ID: 2028164
# City Name: vila velha, City ID: 3445026
# City Name: acapulco, City ID: 3533462
# City Name: qasigiannguit, City ID: 3420768
# City Name: moussoro, City ID: 2427336
# City Name: tiznit, City ID: 2527087
# City Name: rtishchevo, City ID: 500886
# City Name: leningradskiy, City ID: 2123814
# City Name: manggar, City ID: 1636426
# City Name: viedma, City ID: 3832899
# City Name: yerbogachen, City ID: 2012956
# City Name: trowbridge, City ID: 2635427
# City Name: sumbe, City ID: 3346015
# City Name: san luis, City ID: 3837056
# Citymeyungs is not found...
# City Name: laval, City ID: 6050610
# City Name: zimovniki, City ID: 462522
# City Name: sambava, City ID: 1056899
# City Name: alice springs, City ID: 2077895
# City Name: strezhevoy, City ID: 1490796
# City Name: sola, City ID: 2134814
# City Name: anloga, City ID: 2304548
# City Name: newport, City ID: 2641598
# City Name: anastacio, City ID: 3472284
# City Name: banjarmasin, City ID: 1650213
# Citykatsiveli is not found...
# City Name: roald, City ID: 3141667
# City Name: vanimo, City ID: 2084442
# City Name: korgen, City ID: 3149492
# City Name: ridgecrest, City ID: 5387494
# City Name: yulara, City ID: 6355222
# Citysaryshagan is not found...
# City Name: hamilton, City ID: 4513583
# City Name: murchison, City ID: 2186377
# City Name: shurugwi, City ID: 881164
# City Name: huallanca, City ID: 3695465
# City Name: kologriv, City ID: 546282
# City Name: adrar, City ID: 2381972
# City Name: zhengjiatun, City ID: 2033135
# City Name: gerash, City ID: 133595
# City Name: puerto el triunfo, City ID: 3584003
# City Name: chuy, City ID: 3443061
# City Name: erftstadt, City ID: 2929671
# City Name: salaspils, City ID: 455898
# City Name: marivan, City ID: 97572
# City Name: dingle, City ID: 1714733
# Cityduz is not found...
# City Name: olga, City ID: 2018553
# City Name: ahipara, City ID: 2194098
# Citybokspits is not found...
# City Name: buraydah, City ID: 107304
# City Name: pevek, City ID: 2122090
# City Name: grand-lahou, City ID: 2288105
# City Name: tautira, City ID: 4033557
# Citybur gabo is not found...
# City Name: isangel, City ID: 2136825
# City Name: lander, City ID: 5830007
# City Name: ajdabiya, City ID: 89113
# Cityrungata is not found...
# City Name: shenzhen, City ID: 1795565
# City Name: zhigansk, City ID: 2012530
# City Name: acucena, City ID: 3473183
# City Name: jalu, City ID: 86049
# City Name: mbandaka, City ID: 2312895
# City Name: maneromango, City ID: 154915
# City Name: campbell river, City ID: 5914132
# City Name: santa vitoria do palmar, City ID: 3449747
# City Name: galle, City ID: 1246294
# City Name: carbondale, City ID: 4235193
# City Name: bonthe, City ID: 2409914
# City Name: maniitsoq, City ID: 3421982
# City Name: severo-yeniseyskiy, City ID: 1492566
# Citytarudant is not found...
# City Name: greenville, City ID: 4469160
# City Name: kongolo, City ID: 212360
# City Name: portland, City ID: 5746545
# City Name: svetlaya, City ID: 2015852
# City Name: zapadnaya dvina, City ID: 464891
# City Name: caravelas, City ID: 3466980
# Citydianopolis is not found...
# City Name: georgiyevka, City ID: 1524243
# City Name: kerema, City ID: 2094144
# City Name: cabo san lucas, City ID: 3985710
# Citylouisbourg is not found...
# City Name: saint anthony, City ID: 5044290
# City Name: serra, City ID: 3447779
# City Name: port hedland, City ID: 2063042
# City Name: beringovskiy, City ID: 2126710
# City Name: chicama, City ID: 3698359
# City Name: cabedelo, City ID: 3404558
# City Name: fuyang, City ID: 1810845
# City Name: balikpapan, City ID: 1650527
# City Name: marzuq, City ID: 72181
# City Name: jacareacanga, City ID: 3397763
# City Name: daru, City ID: 2098329
# City Name: dong hoi, City ID: 1582886
# City Name: yichun, City ID: 2033413
# City Name: naftalan, City ID: 585400
# City Name: ulaangom, City ID: 1515029
# City Name: taoudenni, City ID: 2450173
# City Name: san martin jilotepeque, City ID: 3589780
# City Name: taman, City ID: 484670
# City Name: gien, City ID: 3016097
# City Name: novobiryusinskiy, City ID: 1497142
# City Name: dawlatabad, City ID: 1142226
# City Name: axim, City ID: 2303611
# City Name: hrusovany nad jevisovkou, City ID: 3074764
# City Name: rio grande, City ID: 3451138
# City Name: malinyi, City ID: 155016
# City Name: vardo, City ID: 777019
# City Name: barra patuca, City ID: 3614835
# City Name: victor harbor, City ID: 2059470
# City Name: bonfim, City ID: 3405215
# City Name: nalut, City ID: 2214432
# City Name: puerto del rosario, City ID: 2512186
# City Name: surt, City ID: 2210554
# City Name: iquitos, City ID: 3696183
# City Name: bollnas, City ID: 2720679
# City Name: santa barbara, City ID: 5392967
# City Name: malanje, City ID: 2239862
# City Name: alofi, City ID: 4036284
# City Name: mulanje, City ID: 925789
# City Name: talnakh, City ID: 1490256
# City Name: itigi, City ID: 158904
# City Name: palmerston, City ID: 6301965
# City Name: yazd, City ID: 111822
# Citysamusu is not found...
# City Name: ugoofaaru, City ID: 1337619
# City Name: kolondieba, City ID: 2454934
# City Name: camacari, City ID: 3468031
# City Name: hobyo, City ID: 57000
# City Name: sorong, City ID: 1626542
# City Name: faya, City ID: 110690
# City Name: cavalcante, City ID: 3466594
# City Name: leh, City ID: 1264976
# City Name: krasnoselkup, City ID: 1502073
# City Name: jiaocheng, City ID: 1806041
# City Name: coruripe, City ID: 3465329
# City Name: yerofey pavlovich, City ID: 2012938
# City Name: mundra, City ID: 1262497
# City Name: texarkana, City ID: 4736096
# City Name: aksarka, City ID: 1512019
# City Name: cidreira, City ID: 3466165
# City Name: taganrog, City ID: 484907
# Cityciras is not found...
# City Name: ruwi, City ID: 287286
# City Name: bom jesus, City ID: 3405304
# City Name: raga, City ID: 368246
# City Name: namatanai, City ID: 2090021
# City Name: shipitsyno, City ID: 494304
# City Name: mareeba, City ID: 2158767
# City Name: asmara, City ID: 343300
# City Name: koslan, City ID: 544084
# City Name: touros, City ID: 3386213
# Citykaramay is not found...
# City Name: garmsar, City ID: 133964
# City Name: qaqortoq, City ID: 3420846
# Citytubruq is not found...
# City Name: blagoyevo, City ID: 576093
# City Name: inuvik, City ID: 5983607
# City Name: boca de parita, City ID: 3714000
# City Name: severobaykalsk, City ID: 2016910
# City Name: sao felix do xingu, City ID: 3388847
# City Name: mnogovershinnyy, City ID: 2019935
# Cityilinsko-podomskoye is not found...
# City Name: sembe, City ID: 2255304
# City Name: padang, City ID: 1633419
# City Name: constitucion, City ID: 3893726
# City Name: hayden, City ID: 5595320
# City Name: nova olinda do norte, City ID: 3393838
# City Name: hualmay, City ID: 3939761
# City Name: hovd, City ID: 1516048
# City Name: beloha, City ID: 1067565
# City Name: manamadurai, City ID: 1263965
# City Name: saint simons, City ID: 4220862
# City Name: sabalgarh, City ID: 1257928
# City Name: khani, City ID: 610864
# City Name: kununurra, City ID: 2068110
# City Name: xiaoweizhai, City ID: 1789945
# City Name: santa cecilia, City ID: 3450376
# City Name: ludvika, City ID: 2693759
# City Name: uusikaupunki, City ID: 633221
# City Name: huarmey, City ID: 3939168
# City Name: veraval, City ID: 1253237
# City Name: benemerito de las americas, City ID: 3816362
# City Name: aleksandrovsk-sakhalinskiy, City ID: 2127282
# City Name: te anau, City ID: 2181625
# City Name: leshukonskoye, City ID: 535839
# City Name: santa rosa, City ID: 1687894
# City Name: dharchula, City ID: 1272864
# City Name: kamenka, City ID: 553766
# City Name: kyren, City ID: 2021031
# City Name: roebourne, City ID: 2062276
# City Name: walvis bay, City ID: 3359638
# City Name: yilan, City ID: 1674199
# City Name: independence, City ID: 4391812
# City Name: agadez, City ID: 2448083
# City Name: la ronge, City ID: 6050066
# City Name: sitka, City ID: 5557293
# City Name: avera, City ID: 4231997
# City Name: sioux lookout, City ID: 6148373
# City Name: orlik, City ID: 1496073
# City Name: brantford, City ID: 5907990
# City Name: kupang, City ID: 2057087
# City Name: puerto madryn, City ID: 3840092
# City Name: ekibastuz, City ID: 1524325
# City Name: chapais, City ID: 5919850
# City Name: san quintin, City ID: 3984997
# Citywarqla is not found...
# City Name: abu samrah, City ID: 172515
# City Name: kaputa, City ID: 176758
# City Name: salalah, City ID: 286621
# City Name: sept-iles, City ID: 6144312

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert the data into a dataframe
cities_df = pd.DataFrame({"City ID": city_id_list, "City": city_name_list, "Country": country_list, "Lat": lat_list, "Lng": lng_list,
                         "Temperature": temp_list, "Humidity": humidity_list, "Clouds": clouds_list,
                         "Wind Speed": wind_speed_list})
cities_df.head()
# Out:
#    City ID       City Country      Lat       Lng  Temperature  Humidity  \
# 0  2163355     Hobart      AU -42.8794  147.3294        57.09        84
# 1  3418910  Upernavik      GL  72.7868  -56.1549        -0.27        87
# 2  3833367    Ushuaia      AR -54.8000  -68.3000        35.82        90
# 3  3691582     Talara      PE  -4.5772  -81.2719        70.27        80
# 4  2075265  Busselton      AU -33.6500  115.3333        73.71        48
#
#    Clouds  Wind Speed
# 0      75        4.61
# 1      41        6.02
# 2      89        1.99
# 3      95       13.49
# 4     100       16.51

# %%
# Export to .csv file
cities_df.to_csv("city_weather.csv", index=False, header=True)
#output_data/cities.csv

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = cities_df["Lat"]
y_values = cities_df["Temperature"]

plt.scatter(x_values,y_values)
plt.title('Temperatures at Latitude Positions')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.ylim(0, 100)
plt.xlim(-60, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("Images/lat_temp.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = cities_df["Lat"]
y_values = cities_df["Humidity"]

plt.scatter(x_values,y_values)
plt.title('Humidity at Latitude Positions')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.ylim(0, 105)
plt.xlim(-60, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("Images/lat_humid.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = cities_df["Lat"]
y_values = cities_df["Clouds"]

plt.scatter(x_values,y_values)
plt.title('Cloudiness at Latitude Positions')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.ylim(-5, 105)
plt.xlim(-60, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("Images/lat_clouds.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = cities_df["Lat"]
y_values = cities_df["Wind Speed"]

plt.scatter(x_values,y_values)
plt.title('Wind Speeds at Latitude Positions')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.ylim(0, 40)
plt.xlim(-60, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("Images/lat_wind.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linear_regression(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    correlation = st.pearsonr(x_values, y_values)
    
    print(f"r-squared: {rvalue**2}")
    print(f"Correlation: {correlation}")
    print(f"Line: {line_eq}")

    return regress_values, line_eq

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
mask = cities_df['Lat'] > 0
northern_hemisphere = cities_df[mask]
southern_hemisphere = cities_df[~mask]

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Temperature"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Temperatures at Latitude Positions (Northern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.ylim(-5, 100)
plt.xlim(0, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("Images/nh_lat_temp_regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Temperature"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Temperatures at Latitude Positions (Southern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-35,80),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.ylim(40, 100)
plt.xlim(0, -60)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("Images/sh_lat_temp_regression.png")

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Humidity at Latitude Positions (Northern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.ylim(0, 105)
plt.xlim(0, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("Images/nh_lat_humid_regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Humidity at Latitude Positions (Southern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-35,80),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.ylim(0, 105)
plt.xlim(0, -60)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
#plt.tight_layout()
plt.show()
plt.savefig("Images/sh_lat_humid_regression.png")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Clouds"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Cloudiness at Latitude Positions (Northern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.ylim(-5, 105)
plt.xlim(0, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("Images/nh_lat_clouds_regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Clouds"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Cloudiness at Latitude Positions (Southern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,60),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.ylim(-5, 105)
plt.xlim(0, -60)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
#plt.tight_layout()
plt.show()
plt.savefig("Images/sh_lat_clouds_regression.png")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Wind Speed at Latitude Positions (Northern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.ylim(0, 40)
plt.xlim(0, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("Images/nh_lat_wind_regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Wind Speed at Latitude Positions (Southern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.ylim(0, 35)
plt.xlim(0, -60)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
#plt.tight_layout()
plt.show()
plt.savefig("Images/sh_lat_wind_regression.png")
